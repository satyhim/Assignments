# %% [markdown]
# <a href="https://colab.research.google.com/github/satyhim/Assignments/blob/main/SQL_Easy_Questions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #SQL Easy and Medium Questions

# %% [markdown]
# ![SQL_Easy_One_to_Six.png](data:image/png;base64,...)

# %% [markdown]
# ![sQL_Easy_seven_to_ten.png](data:image/png;base64,...)
